# %%
pip install python-docx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 1.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 2.1 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import time

from save_book import *


def fetch_catalog():
    with open("catalog.json", "r") as f:
        content = json.load(f)

    urls = list(content.keys())
    summary = list(content.values())

    return urls, summary
    

def fetch_soups():
    promised_soups = prepare_soups(urls)
    soups = []
    
    for i, soup in enumerate(promised_soups):
        # if i % 20 == 0: time.sleep(10)
        print(i)
        soups.append(soup)


urls, summary = fetch_catalog()

# Uncomment to refresh soups. Keep as is to avoid unnecessary requests towards website.
# soups = fetch_soups()

# %%
download(soups)
# Out:
#  -> 0. Load "Rugăciuni care se citesc înainte de orice Acatist"
#  -> 1. Load "Acatistul Sfântului Ierarh Vasile cel Mare"
#  -> 2. Load "Acatistul Sfântului Serafim de Sarov mare făcător de minuni"
#  -> 3. Load "Acatistul Sfântului Mucenic Efrem cel Nou"
#  -> 4. Load "Acatistul Botezului Domnului"
#  -> 5. Load "Acatistul Sfântului Ioan Botezătorul"
#  -> 6. Load "Acatistul Sfântului Antonie cel Mare"
#  -> 7. Load "Acatistul Sfântului Maxim Mărturisitorul"
#  -> 8. Load "Acatistul Sfintei Xenia din Sankt Petersburg"
#  -> 9. Load "Acatistul Sfântului Ierarh Ioan Gură de Aur"
#  -> 10. Load "Acatistul Sfinților Trei Ierarhi: Vasile cel Mare, Grigorie Teologul și Ioan Gură de Aur"
#  -> 11. Load "Acatistul Întâmpinării Domnului"
#  -> 12. Load "Acatistul Sfântului și Dreptului Simeon"
#  -> 13. Load "Acatistul Sfântului Ierarh Fotie Mărturisitorul, Patriarhul Constantinopolului"
#  -> 14. Load "Acatistul Icoanei Maicii Domnului Îndrumătoarea și Ocrotitoarea copiilor"
# ...
